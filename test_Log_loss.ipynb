# %%
# import perceptron
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # графики
from sklearn.metrics import accuracy_score, classification_report, log_loss

# %%
data = pd.read_csv("data.csv", header=None)
targer = np.array([1 if i == 'M' else 0 for i in data[1]])
data = data.drop([0, 1], axis=1)
data = StandardScaler().fit_transform(data)
data
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
data[:, 2:5].shape
# Out:
# (569, 3)

# %%
data.shape
# Out:
# (569, 30)

# %%
targer

# %%
il_log_loss(targer, net.forward(data)[:, 1])

# %%
net = perceptron.Net(2, 2, True, lr=0.01, min_err=0.05)
net.fit(data, targer)
print(classification_report(targer, net.predict(data)))
# Out:
# epoch 1/2000 - loss: (0.6596927533841216, 0.6596927533841216)
# epoch 2/2000 - loss: (0.6597724823146681, 0.6597724823146681)
# epoch 3/2000 - loss: (0.659853884445564, 0.659853884445564)
# epoch 4/2000 - loss: (0.6599369112088997, 0.6599369112088997)
# epoch 5/2000 - loss: (0.660021514942677, 0.660021514942677)
# epoch 6/2000 - loss: (0.6601076488774034, 0.6601076488774034)
# epoch 7/2000 - loss: (0.6601952671228151, 0.6601952671228151)
# epoch 8/2000 - loss: (0.6602843246547271, 0.6602843246547271)
# epoch 9/2000 - loss: (0.6603747773020125, 0.6603747773020125)
# epoch 10/2000 - loss: (0.6604665817337119, 0.6604665817337119)
# epoch 11/2000 - loss: (0.6605596954462729, 0.6605596954462729)
# epoch 12/2000 - loss: (0.6606540767509217, 0.6606540767509217)
# epoch 13/2000 - loss: (0.6607496847611675, 0.6607496847611675)
# epoch 14/2000 - loss: (0.6608464793804387, 0.6608464793804387)
# epoch 15/2000 - loss: (0.6609444212898534, 0.6609444212898534)
# ...

# %%
# tagter * np.log(pred[:, 0]) , (1 - tagter) * np.log(1-pred[:, 1])

# %%
perceptron.il_log_loss(tagter, net.forward(data))

# %%
# log_loss(tagter, net.forward(data))

# %%
# il_log_loss(tagter, net.forward(data))

# %%
logloss2(tagter[0], net.forward(data)[0] )

# %%
tagter = np.array([1, 0])
pred = np.array([[0.9, 0.1], [0.3, 0.7]])
log_loss(tagter, pred), il_log_loss(tagter, pred)

# %%
net.forward(data)

# %%
from sklearn.metrics import log_loss
y_true = np.array([0, 0, 1, 1])
y_pred = np.array([[.9, .1], [.8, .2], [.3, .7], [.01, .99]])
log_loss(y_true, y_pred), il_log_loss(y_true, y_pred)

# %%
from sklearn.metrics import log_loss
y_true = np.array([0, 0, 1, 1])
y_pred = np.array([[.9], [.8], [.3], [.01]])
log_loss(y_true, y_pred)
# Out:
# 2.430291498935543

# %%
def il_log_loss(y_true, y_pred): 
    """Если y_pred масив из двух вероятностей, то первая вероятность - вероятность о нуле?"""
    return np.mean(-(y_true * np.log(y_pred) + (1 - y_true) * np.log((1 - y_pred))))
#     return np.mean(-((y_true * np.log(y_pred[:, 0]))[:,0] + (y_true * np.log(y_pred[:, 1]))[:,1]))

# %%
from sklearn.metrics import log_loss
y_true = np.array([[1],[0]])
# y_pred = net.forward(data)
y_pred1 = np.array([[.9], [.8]])
y_pred2 = np.array([[.9, .1], [.8, .2]])
y_true = np.array([1])
y_pred3 = np.array([[.1795, .8205]])
il_log_loss(y_true, y_pred3)
# il_log_loss(targer, pred[:, 1]),log_loss(y_true, y_pred2)
# Out:
# 0.9577107197528976

# %%
(0 * np.log(0.9) + (1 - 0) * np.log(0.1) + 1 * np.log(0.8) + (1 - 1) * np.log(0.2)) / 2
# Out:
# -1.2628643221541276

# %%
(1 * np.log(0.1) + 1 * np.log(0.8)) /2
# Out:
# -1.2628643221541276

# %%
np.mean(-((y_true * np.log(y_pred2[:, 0]))[:,0] + (y_true * np.log(y_pred2[:, 1]))[:,1]))
# Out:
# 0.8573992140459633

# %%
(y_true * np.log(y_pred2[:, 1]))

# %%
y_pred2[:, 1]

# %%
pred = net.forward(data)

# %%
il_log_loss(targer, pred)

# %%
((y_true * np.log(y_pred[:, 0]))[:,0] + (y_true * np.log(y_pred[:, 1]))[:,1])

# %%
list((targer * np.log(pred[:, 0]))
